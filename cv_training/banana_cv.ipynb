# %%
# !pip install ultralytics roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 51.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.8/95.8 kB 9.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 17.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 94.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 53.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="ZESvCB1NIDM3qQWNc8sS")
project = rf.workspace("melanie-fnxhe").project("banana-ripeness-classification-gf8ob")
version = project.version(1)
dataset = version.download("folder")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Banana-Ripeness-Classification-1 in folder:: 100%|██████████| 13469/13469 [00:01<00:00, 10286.64it/s]

# %%
from ultralytics import YOLO

# Load a pretrained 'classify' model (using 'n' for nano/fast)
model = YOLO('yolov8n-cls.pt') # or 'yolo11n-cls.pt'
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...

# %%
results = model.train(data=dataset.location, epochs=50, imgsz=224)
# Out:
# Ultralytics 8.4.24 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# Load the best weights you just created
model = YOLO('runs/classify/train/weights/best.pt')

# Validate on the 'test' set (the images it hasn't seen yet)
metrics = model.val(data='/content/Banana-Ripeness-Classification-1/test') # use your actual path

print(f"Final Test Accuracy: {metrics.top1 * 100:.2f}%")
# Out:
# Ultralytics 8.4.24 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLOv8n-cls summary (fused): 30 layers, 1,442,566 parameters, 0 gradients, 3.3 GFLOPs
# WARNING ⚠️ Dataset 'split=train' not found at /content/Banana-Ripeness-Classification-1/test/train
# Found 562 images in subdirectories. Attempting to split...
# Splitting /content/Banana-Ripeness-Classification-1/test (6 classes, 562 images) into 80% train, 20% val...
# Split complete in /content/Banana-Ripeness-Classification-1/test_split ✅
# train: /content/Banana-Ripeness-Classification-1/test_split/train... found 447 images in 6 classes ✅
# val: /content/Banana-Ripeness-Classification-1/test_split/val... found 115 images in 6 classes ✅
# test: None...
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 161.4±78.4 MB/s, size: 5.7 KB)
# val: Scanning /content/Banana-Ripeness-Classification-1/test_split/val... 115 images, 0 corrupt: 100% ━━━━━━━━━━━━ 115/115 4.7Kit/s 0.0s
# ...
